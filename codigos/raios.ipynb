# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_excel('/content/powerespec.xls')
df['Power (dBm)'] = df['Power (dBm)']/1000
df['Phase'] = df['Phase'].str.split().str[1]
df['Power (dBm)']
# Out:
#       receiver    Phase      Time (s)  Power (dBm)
# 0            1   69.633  5.950945e-08      -15.362
# 1            1  113.107  7.861804e-08      -15.563
# 2            1    1.893  8.296995e-08      -40.908
# 3            1   34.861  6.515044e-08      -50.389
# 4            1  -12.550  1.901301e-07      -54.697
# ...        ...      ...           ...          ...
# 1220        49   92.505  1.586793e-07      -85.489
# 1221        49  -47.084  2.408374e-07      -87.304
# 1222        49  158.755  3.369876e-07      -88.552
# 1223        49  -74.226  2.282399e-07      -90.032
# 1224        49  -73.005  1.662103e-07      -91.058
#
# [1225 rows x 4 columns]

# %%
df.columns
# Out:
# Index(['receiver', 'Phase', 'Time (s)', 'Power (dBm)'], dtype='object')

# %%
df['Distance (m)'] = df['Time (s)'] * 3*10**8

# %%
len(df['receiver'].unique())
# Out:
# 49

# %%
plt.figure(figsize=(12, 8))


# Gerando o gráfico de potência em função do tempo
power = np.array(df[df['receiver']==1][['Power (dBm)']])
time = np.array(df[df['receiver']==1][['Time (s)']])

#plt.ylim((power.max(), power.min()))
plt.scatter(time,power)
plt.vlines(time,-100,power)
plt.xlabel('Tempo (s)')
plt.ylabel('Potência (dBm)')
plt.title('Gráfico de Potência em Função do Tempo')
plt.grid(True)
plt.axis([min(time)-0.5e-8, max(time)+0.5e-7, min(power)-10, max(power)+10])
# Out:
# (5.450945e-08, 5.4903429e-07, -99.692, -5.362)
